# %% [markdown]
# # Get Dataset

# %%
# %pip install roboflow
# %pip install ultralytics
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.63-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (2024.8.30)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (3.7.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (1.24.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (9.4.0)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: python-dateutil in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Requirement already satisfied: colorama in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->roboflow) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->roboflow) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.63-py3-none-any.whl (85 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/38.8 MB 10.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.5/38.8 MB 10.8 MB/s eta 0:00:04
#    ------- -------------------------------- 6.8/38.8 MB 10.8 MB/s eta 0:00:03
#    --------- ------------------------------ 9.2/38.8 MB 10.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.0/38.8 MB 10.6 MB/s eta 0:00:03
#    ------------- -------------------------- 13.4/38.8 MB 10.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.7/38.8 MB 10.6 MB/s eta 0:00:03
#    ------------------ --------------------- 17.8/38.8 MB 10.7 MB/s eta 0:00:02
#    -------------------- ------------------- 20.2/38.8 MB 10.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.3/38.8 MB 10.7 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/38.8 MB 10.6 MB/s eta 0:00:02
#    --------------------------- ------------ 26.7/38.8 MB 10.7 MB/s eta 0:00:02
#    ------------------------------ --------- 29.1/38.8 MB 10.7 MB/s eta 0:00:01
#    -------------------------------- ------- 31.5/38.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.8/38.8 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 10.1 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-win_amd64.whl (8.6 MB)
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.1/8.6 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.2/8.6 MB 10.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.6/8.6 MB 9.8 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------- -------- 2.1/2.7 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 9.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: filetype, python-dotenv, Pillow, opencv-python-headless, idna, pillow-heif, requests-toolbelt, roboflow
#
#    ---------------------------------------- 0/8 [filetype]
#    ----- ---------------------------------- 1/8 [python-dotenv]
#   Attempting uninstall: Pillow
#    ----- ---------------------------------- 1/8 [python-dotenv]
#     Found existing installation: Pillow 9.4.0
#    ----- ---------------------------------- 1/8 [python-dotenv]
#    ---------- ----------------------------- 2/8 [Pillow]
#     Uninstalling Pillow-9.4.0:
#    ---------- ----------------------------- 2/8 [Pillow]
#       Successfully uninstalled Pillow-9.4.0
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    ---------- ----------------------------- 2/8 [Pillow]
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#   Attempting uninstall: idna
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#     Found existing installation: idna 3.10
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#     Uninstalling idna-3.10:
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#       Successfully uninstalled idna-3.10
#    --------------- ------------------------ 3/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [idna]
#    -------------------- ------------------- 4/8 [idna]
#    ------------------------- -------------- 5/8 [pillow-heif]
#    ------------------------------ --------- 6/8 [requests-toolbelt]
#    ------------------------------ --------- 6/8 [requests-toolbelt]
#    ------------------------------ --------- 6/8 [requests-toolbelt]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ---------------------------------------- 8/8 [roboflow]
#
# Successfully installed Pillow-11.2.1 filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.0 requests-toolbelt-1.0.0 roboflow-1.1.63
# Requirement already satisfied: ultralytics in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (8.3.128)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.24.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (3.7.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.11.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adam ma\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.2)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Kyf3xdcU6QjhCW2ywYKQ")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-6 to yolov5pytorch:: 100%|██████████| 52040/52040 [00:04<00:00, 11234.92it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 2004.21it/s]

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train", "tennis-ball-detection-6/tennis-ball-detection-6/train")
shutil.move("tennis-ball-detection-6/test", "tennis-ball-detection-6/tennis-ball-detection-6/test")
shutil.move("tennis-ball-detection-6/valid", "tennis-ball-detection-6/tennis-ball-detection-6/valid")
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# %yolo task=detect mode=train model=yolov516u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
